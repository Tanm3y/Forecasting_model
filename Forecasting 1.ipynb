# %%
import plotly
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import statsmodels.api as sm
import pylab as py

plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = "17"

from greykite.framework.templates.autogen.forecast_config import EvaluationPeriodParam
from greykite.framework.templates.autogen.forecast_config import ForecastConfig
from greykite.framework.templates.autogen.forecast_config import MetadataParam
from greykite.framework.templates.autogen.forecast_config import ModelComponentsParam
from greykite.framework.templates.forecaster import Forecaster
from greykite.framework.templates.model_templates import ModelTemplateEnum
from greykite.framework.utils.result_summary import summarize_grid_search_results
from greykite.framework.input.univariate_time_series import UnivariateTimeSeries
from greykite.algo.common.seasonality_inferrer import SeasonalityInferConfig
from greykite.algo.common.seasonality_inferrer import SeasonalityInferrer
from greykite.algo.common.seasonality_inferrer import TrendAdjustMethodEnum
from greykite.common import constants as cst
from plotly.offline import init_notebook_mode, iplot

import warnings
from collections import defaultdict
warnings.filterwarnings("ignore")

# %%
path_file = 'C:\\Users\\tayal\\OneDrive\\Desktop\\Product1.xlsx'

df = pd.read_excel(path_file)
Month = UnivariateTimeSeries()
Month.load_data(
     df=df,
     time_col="date",
     value_col="qty",
     freq="D")

# %%
print(Month.describe_time_col())
print(Month.describe_value_col())
print(df.head())
# Out:
# {'data_points': 10227, 'mean_increment_secs': 86400.0, 'min_timestamp': Timestamp('1996-01-01 00:00:00'), 'max_timestamp': Timestamp('2023-12-31 00:00:00')}
# count    10227.000000
# mean       251.400900
# std        144.608247
# min          0.000000
# 25%        124.000000
# 50%        253.000000
# 75%        376.000000
# max        500.000000
# Name: y, dtype: float64
#         date  qty
# 0 1996-01-01   99
# 1 1996-01-02   20
# 2 1996-01-03  339
# 3 1996-01-04   15
# 4 1996-01-05  261

# %%
print(df.tail())
print(df.info())
print(df.describe().T)
# Out:
#             date  qty
# 10222 2023-12-27  317
# 10223 2023-12-28   34
# 10224 2023-12-29  421
# 10225 2023-12-30  266
# 10226 2023-12-31  493
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10227 entries, 0 to 10226
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    10227 non-null  datetime64[ns]
#  1   qty     10227 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 159.9 KB
# None
#        count      mean         std  min    25%    50%    75%    max
# qty  10227.0  251.4009  144.608247  0.0  124.0  253.0  376.0  500.0

# %%
fig = Month.plot()
iplot(fig)

# %% [markdown]
# # Normal Code

# %%
forecast_horizon = 90
meta_data_params = MetadataParam(
     time_col="date",
     value_col="qty",
     freq="D",
 )

# %%
cv_min_train_periods = 821
# Let CV use most recent splits for cross-validation.
cv_use_most_recent_splits = True
# Determine the maximum number of validations.
cv_max_splits = 657
evaluation_period_param = EvaluationPeriodParam(
     test_horizon=forecast_horizon,
     cv_horizon=forecast_horizon,
     periods_between_train_test=0,
     cv_min_train_periods=cv_min_train_periods,
     cv_expanding_window=False,
     cv_use_most_recent_splits=cv_use_most_recent_splits,
     cv_periods_between_splits=None,
     cv_periods_between_train_test=0,
     cv_max_splits=cv_max_splits,
)

# %%
extra_pred_cols = ["ct1"]
autoregression = None

# Specify the model parameters
model_components = ModelComponentsParam(
     growth=dict(growth_term=["linear"]),
     seasonality=dict(
         yearly_seasonality=['auto'],
         quarterly_seasonality=['auto'],
         monthly_seasonality=['auto'],
         weekly_seasonality=[False],
         daily_seasonality=[False]
     ),
     custom=dict(
         fit_algorithm_dict=dict(fit_algorithm="lasso"),
         extra_pred_cols=extra_pred_cols
     ),
     regressors=dict(regressor_cols=None),
     autoregression=autoregression,
     uncertainty=dict(uncertainty_dict={
        "uncertainty_method": "simple_conditional_residuals",
        "params": {
        "conditional_cols": None,
        "quantile_estimation_method": "normal_fit",
        "sample_size_thresh": 5,
        "small_sample_size_method": "std_quantiles",
        "small_sample_size_quantile": 0.98}}
    ),
     events=dict(holiday_lookup_countries=["US"]),
)

# %%
# Run the forecast model
forecaster = Forecaster()
result = forecaster.run_forecast_config(
     df=df,
     config=ForecastConfig(
         model_template=ModelTemplateEnum.SILVERKITE_DAILY_90.name,
         coverage=0.95,
         forecast_horizon=forecast_horizon,
         metadata_param=meta_data_params,
         evaluation_period_param=evaluation_period_param,
         model_components_param=model_components
     )
)
# Out:
# Fitting 92 folds for each of 3 candidates, totalling 276 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Run the forecast model
#       2 forecaster = Forecaster()
# ----> 3 result = forecaster.run_forecast_config(
#       4      df=df,
#       5      config=ForecastConfig(
#       6          model_template=ModelTemplateEnum.SILVERKITE_DAILY_90.name,
#       7          coverage=0.95,
#       8          forecast_horizon=forecast_horizon,
#       9          metadata_param=meta_data_params,
#      10          evaluation_period_param=evaluation_period_param,
#      11          model_components_param=model_components
#      12      )
#      13 )
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\greykite\framework\templates\forecaster.py:378, in Forecaster.run_forecast_config(self, df, config)
#     353 """Creates a forecast from input data and config.
#     354 The result is also stored as ``self.forecast_result``.
#     355
#    (...)
#     373     according to the ``df`` and ``config`` configuration parameters.
#     374 """
#     375 pipeline_parameters = self.apply_forecast_config(
#     376     df=df,
#     377     config=config)
# --> 378 self.forecast_result = forecast_pipeline(**pipeline_parameters)
#     379 return self.forecast_result
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\greykite\framework\pipeline\pipeline.py:209, in validate_pipeline_input.<locals>.pipeline_wrapper(df, time_col, value_col, date_format, tz, freq, train_end_date, anomaly_info, pipeline, regressor_cols, lagged_regressor_cols, estimator, hyperparameter_grid, hyperparameter_budget, n_jobs, verbose, forecast_horizon, coverage, test_horizon, periods_between_train_test, agg_periods, agg_func, score_func, score_func_greater_is_better, cv_report_metrics, null_model_params, relative_error_tolerance, cv_horizon, cv_min_train_periods, cv_expanding_window, cv_use_most_recent_splits, cv_periods_between_splits, cv_periods_between_train_test, cv_max_splits)
#     206 log_message(f"test_horizon: {test_horizon}", LoggingLevelEnum.INFO)
#     207 log_message(f"cv_horizon: {cv_horizon}", LoggingLevelEnum.INFO)
# --> 209 return pipeline_function(
#     210     df,
#     211     time_col=time_col,
#     212     value_col=value_col,
#     213     date_format=date_format,
#     214     tz=tz,
#     215     freq=freq,
#     216     train_end_date=train_end_date,
#     217     anomaly_info=anomaly_info,
#     218     pipeline=pipeline,
#     219     regressor_cols=regressor_cols,
#     220     lagged_regressor_cols=lagged_regressor_cols,
#     221     estimator=estimator,
#     222     hyperparameter_grid=hyperparameter_grid,
#     223     hyperparameter_budget=hyperparameter_budget,
#     224     n_jobs=n_jobs,
#     225     verbose=verbose,
#     226     forecast_horizon=forecast_horizon,
#     227     coverage=coverage,
#     228     test_horizon=test_horizon,
#     229     periods_between_train_test=periods_between_train_test,
#     230     agg_periods=agg_periods,
#     231     agg_func=agg_func,
#     232     score_func=score_func,
#     233     score_func_greater_is_better=score_func_greater_is_better,
#     234     cv_report_metrics=cv_report_metrics,
#     235     null_model_params=null_model_params,
#     236     relative_error_tolerance=relative_error_tolerance,
#     237     cv_horizon=cv_horizon,
#     238     cv_min_train_periods=cv_min_train_periods,
#     239     cv_expanding_window=cv_expanding_window,
#     240     cv_use_most_recent_splits=cv_use_most_recent_splits,
#     241     cv_periods_between_splits=cv_periods_between_splits,
#     242     cv_periods_between_train_test=cv_periods_between_train_test,
#     243     cv_max_splits=cv_max_splits
#     244 )
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\greykite\framework\pipeline\pipeline.py:710, in forecast_pipeline(df, time_col, value_col, date_format, tz, freq, train_end_date, anomaly_info, pipeline, regressor_cols, lagged_regressor_cols, estimator, hyperparameter_grid, hyperparameter_budget, n_jobs, verbose, forecast_horizon, coverage, test_horizon, periods_between_train_test, agg_periods, agg_func, score_func, score_func_greater_is_better, cv_report_metrics, null_model_params, relative_error_tolerance, cv_horizon, cv_min_train_periods, cv_expanding_window, cv_use_most_recent_splits, cv_periods_between_splits, cv_periods_between_train_test, cv_max_splits)
#     696     # Defines grid search approach for CV
#     697     grid_search = get_hyperparameter_searcher(
#     698         hyperparameter_grid=hyperparameter_grid,
#     699         model=pipeline,
#    (...)
#     708         agg_func=agg_func,
#     709         relative_error_tolerance=relative_error_tolerance)
# --> 710     grid_search.fit(train_df, train_y)
#     711     best_estimator = grid_search.best_estimator_
#     713 # Evaluates historical performance, fits model to all data (train+test)
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\sklearn\model_selection\_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\sklearn\model_selection\_search.py:1809, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1807 def _run_search(self, evaluate_candidates):
#    1808     """Search n_iter candidates from param_distributions"""
# -> 1809     evaluate_candidates(
#    1810         ParameterSampler(
#    1811             self.param_distributions, self.n_iter, random_state=self.random_state
#    1812         )
#    1813     )
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\sklearn\model_selection\_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\sklearn\model_selection\_validation.py:729, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     727         estimator.fit(X_train, **fit_params)
#     728     else:
# --> 729         estimator.fit(X_train, y_train, **fit_params)
#     731 except Exception:
#     732     # Note fit time as time until error
#     733     fit_time = time.time() - start_time
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\sklearn\pipeline.py:427, in Pipeline.fit(self, X, y, **fit_params)
#     425     if self._final_estimator != "passthrough":
#     426         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 427         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     429 return self
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\greykite\sklearn\estimator\simple_silverkite_estimator.py:276, in SimpleSilverkiteEstimator.fit(self, X, y, time_col, value_col, **fit_params)
#     273     if uncertainty_method == UncertaintyMethodEnum.simple_conditional_residuals.name:
#     274         uncertainty_dict = self.uncertainty_dict
# --> 276 self.model_dict = self.silverkite.forecast_simple(
#     277     df=X,
#     278     time_col=time_col,
#     279     value_col=value_col,
#     280     time_properties=self.time_properties,
#     281     freq=self.freq,
#     282     forecast_horizon=self.forecast_horizon,
#     283     origin_for_time_vars=self.origin_for_time_vars,
#     284     train_test_thresh=self.train_test_thresh,
#     285     training_fraction=self.training_fraction,
#     286     fit_algorithm=self.fit_algorithm_dict["fit_algorithm"],
#     287     fit_algorithm_params=self.fit_algorithm_dict["fit_algorithm_params"],
#     288     auto_holiday=self.auto_holiday,
#     289     holidays_to_model_separately=self.holidays_to_model_separately,
#     290     holiday_lookup_countries=self.holiday_lookup_countries,
#     291     holiday_pre_num_days=self.holiday_pre_num_days,
#     292     holiday_post_num_days=self.holiday_post_num_days,
#     293     holiday_pre_post_num_dict=self.holiday_pre_post_num_dict,
#     294     daily_event_df_dict=self.daily_event_df_dict,
#     295     auto_holiday_params=self.auto_holiday_params,
#     296     daily_event_neighbor_impact=self.daily_event_neighbor_impact,
#     297     daily_event_shifted_effect=self.daily_event_shifted_effect,
#     298     auto_growth=self.auto_growth,
#     299     changepoints_dict=self.changepoints_dict,
#     300     auto_seasonality=self.auto_seasonality,
#     301     yearly_seasonality=self.yearly_seasonality,
#     302     quarterly_seasonality=self.quarterly_seasonality,
#     303     monthly_seasonality=self.monthly_seasonality,
#     304     weekly_seasonality=self.weekly_seasonality,
#     305     daily_seasonality=self.daily_seasonality,
#     306     max_daily_seas_interaction_order=self.max_daily_seas_interaction_order,
#     307     max_weekly_seas_interaction_order=self.max_weekly_seas_interaction_order,
#     308     autoreg_dict=self.autoreg_dict,
#     309     past_df=self.past_df,
#     310     lagged_regressor_dict=self.lagged_regressor_dict,
#     311     seasonality_changepoints_dict=self.seasonality_changepoints_dict,
#     312     min_admissible_value=self.min_admissible_value,
#     313     max_admissible_value=self.max_admissible_value,
#     314     uncertainty_dict=uncertainty_dict,
#     315     normalize_method=self.normalize_method,
#     316     growth_term=self.growth_term,
#     317     regressor_cols=self.regressor_cols,
#     318     feature_sets_enabled=self.feature_sets_enabled,
#     319     extra_pred_cols=self.extra_pred_cols,
#     320     drop_pred_cols=self.drop_pred_cols,
#     321     explicit_pred_cols=self.explicit_pred_cols,
#     322     regression_weight_col=self.regression_weight_col,
#     323     simulation_based=self.simulation_based,
#     324     simulation_num=self.simulation_num,
#     325     fast_simulation=self.fast_simulation,
#     326     remove_intercept=self.remove_intercept)
#     328 # Fits the uncertainty model if not already fit.
#     329 if self.uncertainty_dict is not None and uncertainty_dict is None:
#     330     # The quantile regression model.
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\greykite\algo\forecast\silverkite\forecast_simple_silverkite.py:908, in SimpleSilverkiteForecast.forecast_simple(self, *args, **kwargs)
#     886 """A wrapper around ``SilverkiteForecast::forecast`` that simplifies some of the input parameters.
#     887
#     888 Parameters
#    (...)
#     905     :func:`~greykite.algo.common.ml_models.fit_ml_model_with_evaluation`.
#     906 """
#     907 parameters = self.convert_params(*args, **kwargs)
# --> 908 trained_model = super().forecast(**parameters)
#     909 return trained_model
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\greykite\algo\forecast\silverkite\forecast_silverkite.py:1002, in SilverkiteForecast.forecast(self, df, time_col, value_col, freq, origin_for_time_vars, extra_pred_cols, drop_pred_cols, explicit_pred_cols, train_test_thresh, training_fraction, fit_algorithm, fit_algorithm_params, daily_event_df_dict, daily_event_neighbor_impact, daily_event_shifted_effect, fs_components_df, autoreg_dict, past_df, lagged_regressor_dict, changepoints_dict, seasonality_changepoints_dict, changepoint_detector, min_admissible_value, max_admissible_value, uncertainty_dict, normalize_method, adjust_anomalous_dict, impute_dict, regression_weight_col, forecast_horizon, simulation_based, simulation_num, fast_simulation, remove_intercept)
#     999     ind_train = np.where(df[time_col] < train_test_thresh)[0].tolist()
#    1000     ind_test = np.where(df[time_col] >= train_test_thresh)[0].tolist()
# -> 1002 trained_model = fit_ml_model_with_evaluation(
#    1003     df=features_df,
#    1004     model_formula_str=model_formula_str,
#    1005     fit_algorithm=fit_algorithm,
#    1006     fit_algorithm_params=fit_algorithm_params,
#    1007     ind_train=ind_train,
#    1008     ind_test=ind_test,
#    1009     training_fraction=training_fraction,
#    1010     randomize_training=False,
#    1011     min_admissible_value=min_admissible_value,
#    1012     max_admissible_value=max_admissible_value,
#    1013     uncertainty_dict=uncertainty_dict,
#    1014     normalize_method=normalize_method,
#    1015     regression_weight_col=regression_weight_col,
#    1016     remove_intercept=remove_intercept)
#    1018 # Normalizes the changepoint_values
#    1019 normalized_changepoint_values = self.__normalize_changepoint_values(
#    1020     changepoint_values=changepoint_values,
#    1021     pred_cols=pred_cols,
#    1022     continuous_time_col=continuous_time_col,
#    1023     normalize_df_func=trained_model["normalize_df_func"]
#    1024 )
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\greykite\algo\common\ml_models.py:940, in fit_ml_model_with_evaluation(df, model_formula_str, y_col, pred_cols, fit_algorithm, fit_algorithm_params, ind_train, ind_test, training_fraction, randomize_training, min_admissible_value, max_admissible_value, uncertainty_dict, normalize_method, regression_weight_col, remove_intercept)
#     931         raise ValueError(
#     932             f"Model training requires at least 3 observations, but the dataframe passed "
#     933             f"to training has {nrows} rows after removing NAs."
#     934             f"Sometimes this can be caused by unnecessary columns in your training data "
#     935             f"which contain NAs. Make sure to remove unnecessary columns from data before "
#     936             f"passing it to the function.")
#     938 # an internal function for fitting model
#     939 # this is wrapped into a function since we can do evaluations
# --> 940 trained_model = fit_ml_model(
#     941     df=df,
#     942     model_formula_str=model_formula_str,
#     943     fit_algorithm=fit_algorithm,
#     944     fit_algorithm_params=fit_algorithm_params,
#     945     y_col=y_col,
#     946     pred_cols=pred_cols,
#     947     min_admissible_value=min_admissible_value,
#     948     max_admissible_value=max_admissible_value,
#     949     uncertainty_dict=uncertainty_dict,
#     950     normalize_method=normalize_method,
#     951     regression_weight_col=regression_weight_col,
#     952     remove_intercept=remove_intercept)
#     954 # we store the obtained ``y_col`` from the function in a new variable (``y_col_final``)
#     955 # this is done since the input y_col could be None
#     956 # in which case we extract ``y_col`` from the formula (``model_formula_str``)
#     957 y_col_final = trained_model["y_col"]
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\greykite\algo\common\ml_models.py:535, in fit_ml_model(df, model_formula_str, fit_algorithm, fit_algorithm_params, y_col, pred_cols, min_admissible_value, max_admissible_value, uncertainty_dict, normalize_method, regression_weight_col, remove_intercept)
#     532     sample_weight = df[regression_weight_col]
#     534 # Prediction model generated by using all observed data.
# --> 535 ml_model = fit_model_via_design_matrix(
#     536     x_train=x_mat,
#     537     y_train=y,
#     538     fit_algorithm=fit_algorithm,
#     539     fit_algorithm_params=fit_algorithm_params,
#     540     sample_weight=sample_weight)
#     542 # Obtains `alpha`, `p_effective`, `h_mat` (H), and `sigma_scaler`.
#     543 # See comments below the variables.
#     544 # Read more at https://online.stat.psu.edu/stat508/lesson/5/5.1 or
#     545 # book: “Applied Regression Analysis” by Norman R. Draper, Harry Smith.
#     546 alpha = None
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\greykite\algo\common\ml_models.py:342, in fit_model_via_design_matrix(x_train, y_train, fit_algorithm, sample_weight, fit_algorithm_params)
#     337         ml_model.fit(
#     338             X=x_train,
#     339             y=y_train,
#     340             sample_weight=sample_weight)
#     341     else:
# --> 342         ml_model.fit(
#     343             X=x_train,
#     344             y=y_train)
#     346 return ml_model
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1663, in LinearModelCV.fit(self, X, y, sample_weight)
#    1643 # We do a double for loop folded in one, in order to be able to
#    1644 # iterate in parallel on l1_ratio and folds
#    1645 jobs = (
#    1646     delayed(_path_residuals)(
#    1647         X,
#    (...)
#    1661     for train, test in folds
#    1662 )
# -> 1663 mse_paths = Parallel(
#    1664     n_jobs=self.n_jobs,
#    1665     verbose=self.verbose,
#    1666     prefer="threads",
#    1667 )(jobs)
#    1668 mse_paths = np.reshape(mse_paths, (n_l1_ratio, len(folds), -1))
#    1669 # The mean is computed over folds.
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1389, in _path_residuals(X, y, sample_weight, train, test, fit_intercept, path, path_params, alphas, l1_ratio, X_order, dtype)
#    1386 # Do the ordering and type casting here, as if it is done in the path,
#    1387 # X is copied and a reference is kept here
#    1388 X_train = check_array(X_train, accept_sparse="csc", dtype=dtype, order=X_order)
# -> 1389 alphas, coefs, _ = path(X_train, y_train, **path_params)
#    1390 del X_train, y_train
#    1392 if y.ndim == 1:
#    1393     # Doing this so that it becomes coherent with multioutput.
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:329, in lasso_path(X, y, eps, n_alphas, alphas, precompute, Xy, copy_X, coef_init, verbose, return_n_iter, positive, **params)
#     173 def lasso_path(
#     174     X,
#     175     y,
#    (...)
#     187     **params,
#     188 ):
#     189     """Compute Lasso path with coordinate descent.
#     190
#     191     The Lasso optimization function varies for mono and multi-outputs.
#    (...)
#     327      [0.2159048  0.4425765  0.23668876]]
#     328     """
# --> 329     return enet_path(
#     330         X,
#     331         y,
#     332         l1_ratio=1.0,
#     333         eps=eps,
#     334         n_alphas=n_alphas,
#     335         alphas=alphas,
#     336         precompute=precompute,
#     337         Xy=Xy,
#     338         copy_X=copy_X,
#     339         coef_init=coef_init,
#     340         verbose=verbose,
#     341         positive=positive,
#     342         return_n_iter=return_n_iter,
#     343         **params,
#     344     )
#
# File c:\Users\tayal\anaconda3\envs\greykite\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628, in enet_path(X, y, l1_ratio, eps, n_alphas, alphas, precompute, Xy, copy_X, coef_init, verbose, return_n_iter, positive, check_input, **params)
#     614     model = cd_fast.enet_coordinate_descent_gram(
#     615         coef_,
#     616         l1_reg,
#    (...)
#     625         positive,
#     626     )
#     627 elif precompute is False:
# --> 628     model = cd_fast.enet_coordinate_descent(
#     629         coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
#     630     )
#     631 else:
#     632     raise ValueError(
#     633         "Precompute should be one of True, False, 'auto' or array-like. Got %r"
#     634         % precompute
#     635     )
#
# KeyboardInterrupt:

# %%
# Get the useful fields from the forecast result
model = result.model[-1]
backtest = result.backtest
forecast = result.forecast
grid_search = result.grid_search\

# Check model coefficients / variables
# Get model summary with p-values
print(model.summary())
# Out:
# ================================ Model Summary =================================
#
# Number of observations: 144,   Number of features: 7
# Method: Lasso regression
# Number of nonzero features: 5
# Regularization parameter: 0.5727
#
# Residuals:
#          Min           1Q       Median           3Q          Max
#       -104.8       -22.46       -3.335         15.5        146.9
#
#          Pred_col Estimate Pr(>)_split sig. code             95%CI  Prob_nonzero
#         Intercept    131.8      <2e-16       ***    (12.88, 239.1)          1.00
#      events_Other   -8.946       1.000             (-90.61, 66.45)          0.83
#               ct1       0.       1.000           (-1310.0, 1330.0)          0.24
# cp0_1950_05_20_00    199.8       0.001        ** (-1039.0, 1263.0)          0.98
# cp1_1954_09_04_00    31.72       1.000             (-181.9, 263.7)          0.77
# cp2_1958_12_20_00       0.       1.000             (-180.1, 229.0)          0.27
#    y_avglag_1_2_3    153.7       0.011         *   (-137.5, 569.6)          0.97
# Signif. Code: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Multiple R-squared: 0.8765,   Adjusted R-squared: 0.873
# F-statistic: 237.82 on 3 and 139 DF,   p-value: 1.110e-16
# Model AIC: 1802.1,   model BIC: 1817.0
#
# WARNING: the F-ratio and its p-value on regularized methods might be misleading, they are provided only for reference purposes.

# %%
fig = forecast.plot()
iplot(fig)

# %%
fig=forecast.plot_components()
iplot(fig)

# %%
# Get cross-validation results
cv_results = summarize_grid_search_results(
     grid_search=grid_search,
     decimals=2,
     cv_report_metrics=None,
     column_order=[
         "rank", "mean_test", "split_test", "mean_train", "split_train",
         "mean_fit_time", "mean_score_time", "params"])
# Transposes to save space in the printed output
print(cv_results.transpose())
# Out:
#                          0
# rank_test_MAPE           1
# mean_test_MAPE       11.55
# split_test_MAPE   (11.55,)
# mean_train_MAPE       9.28
# split_train_MAPE   (9.28,)
# mean_fit_time         0.63
# mean_score_time       0.74
# params                  []

# %%
# Check historical evaluation metrics (on the historical training/test set).
backtest_eval = defaultdict(list)
for metric, value in backtest.train_evaluation.items():
    backtest_eval[metric].append(value)
    backtest_eval[metric].append(backtest.test_evaluation[metric])
metrics = pd.DataFrame(backtest_eval, index=["train", "test"]).T
print(metrics)
# Out:
#                                                          train         test
# CORR                                                  0.929092     0.542434
# R2                                                    0.863211     0.270862
# MSE                                                 992.394718  4461.086853
# RMSE                                                 31.502297    66.791368
# MAE                                                  22.349179    56.135816
# MedAE                                                17.290882    51.990903
# MAPE                                                  9.521339    13.233279
# MedAPE                                                8.310619    11.860122
# sMAPE                                                 4.656115     6.428517
# Q80                                                  11.174589    24.827746
# Q95                                                  11.174589    23.207665
# Q99                                                  11.174589    22.775643
# OutsideTolerance1p                                    0.842593     0.944444
# OutsideTolerance2p                                    0.787037     0.944444
# OutsideTolerance3p                                    0.740741     0.888889
# OutsideTolerance4p                                    0.666667     0.861111
# OutsideTolerance5p                                    0.555556     0.833333
# Outside Tolerance (fraction)                              None         None
# R2_null_model_score                                       None         None
# Prediction Band Width (%)                            61.448948     29.86866
# Prediction Band Coverage (fraction)                   0.935185     0.638889
# Coverage: Lower Band                                  0.472222     0.472222
# Coverage: Upper Band                                  0.462963     0.166667
# Coverage Diff: Actual_Coverage - Intended_Coverage   -0.014815    -0.311111
# MIS                                                 171.298173    647.37505

# %%
fig = backtest.plot()
iplot(fig)

# %%
pd.DataFrame(result.backtest.test_evaluation, index=["Value"]).transpose()
# Out:
#                                                           Value
# CORR                                                   0.542434
# R2                                                     0.270862
# MSE                                                 4461.086853
# RMSE                                                  66.791368
# MAE                                                   56.135816
# MedAE                                                 51.990903
# MAPE                                                  13.233279
# MedAPE                                                11.860122
# sMAPE                                                  6.428517
# Q80                                                   24.827746
# Q95                                                   23.207665
# Q99                                                   22.775643
# OutsideTolerance1p                                     0.944444
# OutsideTolerance2p                                     0.944444
# OutsideTolerance3p                                     0.888889
# OutsideTolerance4p                                     0.861111
# OutsideTolerance5p                                     0.833333
# Outside Tolerance (fraction)                               None
# R2_null_model_score                                        None
# Prediction Band Width (%)                              29.86866
# Prediction Band Coverage (fraction)                    0.638889
# Coverage: Lower Band                                   0.472222
# Coverage: Upper Band                                   0.166667
# Coverage Diff: Actual_Coverage - Intended_Coverage    -0.311111
# MIS                                                   647.37505

# %%
model = result.model
future_df = result.timeseries.make_future_dataframe(
    periods=90,
    include_history=False
)

# %%
model.predict(future_df)
# Out:
#            ts    forecast                         quantile_summary    err_std  \
# 0  1961-01-01  458.412408  (375.79531439065084, 541.0295023030798)  42.152353
# 1  1961-02-01  469.131694    (386.5145999351901, 551.748787847619)  42.152353
# 2  1961-03-01  479.508975  (396.89188123590543, 562.1260691483343)  42.152353
# 3  1961-04-01  486.678706    (404.0616124860931, 569.295800398522)  42.152353
# 4  1961-05-01  491.709549  (409.09245519798395, 574.3266431104129)  42.152353
# 5  1961-06-01  496.193881  (413.57678677319234, 578.8109746856212)  42.152353
# 6  1961-07-01  499.977260    (417.3601657570422, 582.594353669471)  42.152353
# 7  1961-08-01  503.462092   (420.8449981270998, 586.0791860395287)  42.152353
# 8  1961-09-01  506.780399   (424.1633054601316, 589.3974933725605)  42.152353
# 9  1961-10-01  509.906904   (427.2898103800665, 592.5239982924954)  42.152353
# 10 1961-11-01  513.028862   (430.4117683099145, 595.6459562223434)  42.152353
# 11 1961-12-01  516.045527  (433.42843330652653, 598.6626212189555)  42.152353
# 12 1962-01-01  510.150315    (427.5332206517771, 592.767408564206)  42.152353
# 13 1962-02-01  521.174535   (438.5574412201092, 603.7916291325381)  42.152353
# 14 1962-03-01  523.905716  (441.28862245749013, 606.5228103699191)  42.152353
# 15 1962-04-01  526.804768   (444.1876736319393, 609.4218615443682)  42.152353
# 16 1962-05-01  530.584866    (447.9677724868831, 613.201960399312)  42.152353
# 17 1962-06-01  533.650888   (451.0337937431264, 616.2679816555553)  42.152353
# 18 1962-07-01  536.686769    (454.0696748144631, 619.303862726892)  42.152353
# 19 1962-08-01  539.803595   (457.1865009379582, 622.4206888503871)  42.152353
# 20 1962-09-01  542.848978  (460.23188412658493, 625.4660720390139)  42.152353
# 21 1962-10-01  545.825932   (463.2088376053708, 628.4430255177997)  42.152353
# 22 1962-11-01  548.862745   (466.2456505573336, 631.4798384697625)  42.152353
# 23 1962-12-01  551.824732   (469.2076383432972, 634.4418262557261)  42.152353
# 24 1963-01-01  545.898350  (463.28125645694917, 628.5154443693781)  42.152353
# 25 1963-02-01  556.904153    (474.287059067911, 639.5212469803399)  42.152353
# 26 1963-03-01  559.624104      (477.007009699301, 642.24119761173)  42.152353
# 27 1963-04-01  562.516604   (479.8995100213503, 645.1336979337792)  42.152353
# 28 1963-05-01  566.292804   (483.6757097374029, 648.9098976498318)  42.152353
# 29 1963-06-01  569.356490   (486.7393957167289, 651.9735836291578)  42.152353
# 30 1963-07-01  572.390994   (489.7738996515715, 655.0080875640004)  42.152353
# 31 1963-08-01  575.507000   (492.8899059137795, 658.1240938262084)  42.152353
# 32 1963-09-01  578.551895   (495.9348009186005, 661.1689888310294)  42.152353
# 33 1963-10-01  581.528559   (498.9114651690733, 664.1456530815022)  42.152353
# 34 1963-11-01  584.565200    (501.948106074313, 667.1822939867419)  42.152353
# 35 1963-12-01  587.527086  (504.90999159144684, 670.1441795038758)  42.152353
#
#     forecast_lower  forecast_upper
# 0       375.795314      541.029502
# 1       386.514600      551.748788
# 2       396.891881      562.126069
# 3       404.061612      569.295800
# 4       409.092455      574.326643
# 5       413.576787      578.810975
# 6       417.360166      582.594354
# 7       420.844998      586.079186
# 8       424.163305      589.397493
# 9       427.289810      592.523998
# 10      430.411768      595.645956
# 11      433.428433      598.662621
# 12      427.533221      592.767409
# 13      438.557441      603.791629
# 14      441.288622      606.522810
# 15      444.187674      609.421862
# 16      447.967772      613.201960
# 17      451.033794      616.267982
# 18      454.069675      619.303863
# 19      457.186501      622.420689
# 20      460.231884      625.466072
# 21      463.208838      628.443026
# 22      466.245651      631.479838
# 23      469.207638      634.441826
# 24      463.281256      628.515444
# 25      474.287059      639.521247
# 26      477.007010      642.241198
# 27      479.899510      645.133698
# 28      483.675710      648.909898
# 29      486.739396      651.973584
# 30      489.773900      655.008088
# 31      492.889906      658.124094
# 32      495.934801      661.168989
# 33      498.911465      664.145653
# 34      501.948106      667.182294
# 35      504.909992      670.144180

# %% [markdown]
# # Changepoints

# %%
from greykite.algo.changepoint.adalasso.changepoint_detector import ChangepointDetector

model1 = ChangepointDetector()
res = model1.find_trend_changepoints(
     df=df,            # data df
     time_col="date",    # time column name
     value_col="qty")    # value column name
pd.DataFrame({"trend_changepoints": res["trend_changepoints"]})  # prints a dataframe showing the result
# Out:
#   trend_changepoints
# 0         1949-06-01
# 1         1949-08-01
# 2         1950-07-01
# 3         1953-07-01
# 4         1953-08-01
# 5         1954-08-01
# 6         1958-12-01

# %%
# specify dataset information
metadata1 = dict(
     time_col="date",  # name of the time column ("datepartition" in example above)
     value_col="qty",  # name of the value column ("macrosessions" in example above)
     freq="D"        # "H" for hourly, "D" for daily, "W" for weekly, etc.
     # Any format accepted by ``pd.date_range``
 )
 # specify changepoint parameters in model_components
model_components1 = dict(
     changepoints={
         # it's ok to provide one of ``changepoints_dict`` or ``seasonality_changepoints_dict`` by itself
         "changepoints_dict": {
             "method": "auto",
             "continuous_time_col":"ct1",
             "growth_function":"linear",
             "yearly_seasonality_order": 12,
             "regularization_strength": 0.46,
             "resample_freq": "1M",
             "potential_changepoint_n": 30,
             "no_changepoint_proportion_from_end": 0.3
         },
     },
     custom={
         "fit_algorithm_dict": {
             "fit_algorithm": "lasso"}})

# %%
# Generates model config
config1 = ForecastConfig.from_dict(
     dict(
         model_template=ModelTemplateEnum.SILVERKITE_DAILY_90.name,
         forecast_horizon=90,  # forecast 3 years
         coverage=0.95,  # 95% prediction intervals
         metadata_param=metadata1,
         model_components_param=model_components1))

 # Then run with changepoint parameters
forecaster1 = Forecaster()
result1 = forecaster1.run_forecast_config(
     df=df,
     config=config1)
# Out:
# Fitting 1 folds for each of 1 candidates, totalling 1 fits

# %%
forecast1 = result1.forecast
fig = forecast1.plot()
iplot(fig)

# %%
fig=forecast1.plot_components()
iplot(fig)

# %%
# Get the useful fields from the forecast result
model1 = result1.model[-1]
backtest1 = result1.backtest
forecast1 = result1.forecast
grid_search = result1.grid_search\

# Check model coefficients / variables
# Get model summary with p-values
print(model1.summary())
# Out:
# ================================ Model Summary =================================
#
# Number of observations: 144,   Number of features: 28
# Method: Lasso regression
# Number of nonzero features: 25
# Regularization parameter: 0.03539
#
# Residuals:
#          Min           1Q       Median           3Q          Max
#       -21.86       -3.867       0.4936        4.893        18.97
#
#            Pred_col Estimate Pr(>)_split sig. code                95%CI  Prob_nonzero
#           Intercept    111.7      <2e-16       ***      (-465.4, 327.0)          1.00
# C(month,... 13)))_2    10.61       0.630                (-105.2, 99.26)          0.76
# C(month,... 13)))_3    21.85    9.17e-04       ***      (-63.04, 120.4)          0.99
# C(month,... 13)))_4    1.065       0.161                (-139.0, 134.8)          0.63
# C(month,... 13)))_5   -9.156       0.745                (-233.2, 450.4)          0.79
# C(month,... 13)))_6    -13.7       0.083         .      (-146.3, 88.59)          0.77
# C(month,... 13)))_7   -20.34       0.033         *      (-207.8, 95.95)          0.90
# C(month,... 13)))_8   -11.06       0.680                (-111.2, 73.31)          0.89
# C(month,... 13)))_9   0.9987       1.000                (-87.91, 90.51)          0.61
# C(month,...13)))_10   -2.119       1.000                (-100.9, 111.7)          0.60
# C(month,...13)))_11   -2.836       1.000                (-324.2, 281.4)          0.70
# C(month,...13)))_12       0.       1.000                (-73.62, 79.32)          0.37
#      y_avglag_1_2_3    213.0    3.62e-13       ***       (-90.8, 696.6)          1.00
# y_avglag... 13)))_2   -32.66       0.020         *      (-284.9, 366.5)          0.98
# y_avglag... 13)))_3       0.       0.625                (-147.9, 167.8)          0.66
# y_avglag... 13)))_4    18.32       0.340                (-147.8, 300.9)          0.73
# y_avglag... 13)))_5    36.06       0.012         *      (-948.4, 423.2)          0.94
# y_avglag... 13)))_6    99.37    6.48e-11       ***      (-99.24, 320.9)          1.00
# y_avglag... 13)))_7    169.6    4.49e-15       ***      (-15.48, 426.5)          1.00
# y_avglag... 13)))_8    130.3    3.94e-10       ***       (-33.6, 280.4)          0.98
# y_avglag... 13)))_9       0.       1.000                (-250.9, 164.8)          0.35
# y_avglag...13)))_10    -55.0    1.25e-08       ***      (-342.4, 85.46)          0.98
# y_avglag...13)))_11   -91.78    1.83e-11       ***      (-625.8, 586.8)          0.98
# y_avglag...13)))_12   -19.71       0.031         *      (-161.2, 91.06)          0.94
#                 ct1    105.9       1.000           (-5889.0, 1.695e+04)          1.00
#   cp0_1949_05_31_00    23.81       1.000           (-1.617e+04, 5607.0)          0.98
#   cp1_1950_07_31_00    23.46       1.000                (-370.9, 427.8)          0.74
#   cp2_1954_06_30_00     37.5       0.003        **      (-47.35, 114.8)          1.00
# Signif. Code: 0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Multiple R-squared: 0.9956,   Adjusted R-squared: 0.9947
# F-statistic: 1105.3 on 24 and 118 DF,   p-value: 1.110e-16
# Model AIC: 1363.3,   model BIC: 1437.6
#
# WARNING: the condition number is large, 5.04e+05. This might indicate that there are strong multicollinearity or other numerical problems.
# WARNING: the F-ratio and its p-value on regularized methods might be misleading, they are provided only for reference purposes.

# %%
backtest1 = result1.backtest
backtest_eval1 = defaultdict(list)
for metric, value in backtest1.train_evaluation.items():
    backtest_eval1[metric].append(value)
    backtest_eval1[metric].append(backtest1.test_evaluation[metric])
metrics1 = pd.DataFrame(backtest_eval1, index=["train", "test"]).T
metrics1.head()
# Out:
#           train        test
# CORR   0.997784    0.987993
# R2     0.995564    0.873565
# MSE   32.182037  773.568473
# RMSE   5.672921   27.813099
# MAE    4.344461   24.553929

# %%
pd.DataFrame(result1.backtest.test_evaluation, index=["Value"]).transpose()
# Out:
#                                                          Value
# CORR                                                  0.987993
# R2                                                    0.873565
# MSE                                                 773.568473
# RMSE                                                 27.813099
# MAE                                                  24.553929
# MedAE                                                25.420445
# MAPE                                                  6.174095
# MedAPE                                                5.488894
# sMAPE                                                 2.964961
# Q80                                                   4.910786
# Q95                                                   1.227696
# Q99                                                   0.245539
# OutsideTolerance1p                                    0.916667
# OutsideTolerance2p                                    0.833333
# OutsideTolerance3p                                    0.805556
# OutsideTolerance4p                                        0.75
# OutsideTolerance5p                                    0.638889
# Outside Tolerance (fraction)                              None
# R2_null_model_score                                       None
# Prediction Band Width (%)                             5.378737
# Prediction Band Coverage (fraction)                   0.166667
# Coverage: Lower Band                                  0.166667
# Coverage: Upper Band                                       0.0
# Coverage Diff: Actual_Coverage - Intended_Coverage   -0.783333
# MIS                                                 602.861425

# %%
model1 = result1.model
future_df1 = result1.timeseries.make_future_dataframe(
    periods=90,
    include_history=False
)

# %%
model1.predict(future_df1)
# Out:
#            ts    forecast                         quantile_summary   err_std  \
# 0  1961-01-01  445.333607  (429.66472181541485, 461.0024929964301)  7.994476
# 1  1961-02-01  420.264574  (404.59568889121795, 435.9334600722332)  7.994476
# 2  1961-03-01  472.442748   (456.77386268153975, 488.111633862555)  7.994476
# 3  1961-04-01  479.293335  (463.62444931394054, 494.9622204949558)  7.994476
# 4  1961-05-01  494.656855  (478.9879690067688, 510.32574018778405)  7.994476
# 5  1961-06-01  570.216461    (554.547575454454, 585.8853466354691)  7.994476
# 6  1961-07-01  651.852639   (636.1837529397925, 667.5215241208076)  7.994476
# 7  1961-08-01  647.448089   (631.7792034845876, 663.1169746656027)  7.994476
# 8  1961-09-01  546.566852   (530.8979667702795, 562.2357379512946)  7.994476
# 9  1961-10-01  483.002910  (467.33402469725615, 498.6717958782714)  7.994476
# 10 1961-11-01  419.462497  (403.79361116409336, 435.1313823451086)  7.994476
# 11 1961-12-01  466.555090  (450.88620490577455, 482.2239760867898)  7.994476
# 12 1962-01-01  477.243901   (461.5750150476381, 492.9127862286533)  7.994476
# 13 1962-02-01  451.007334   (435.3384481251627, 466.6762193061779)  7.994476
# 14 1962-03-01  506.022793   (490.3539075307675, 521.6916787117827)  7.994476
# 15 1962-04-01  514.164647   (498.4957615119236, 529.8335326929388)  7.994476
# 16 1962-05-01  531.347630   (515.6787447770531, 547.0165159580682)  7.994476
# 17 1962-06-01  612.708380   (597.0394948365816, 628.3772660175968)  7.994476
# 18 1962-07-01  701.125203    (685.456316973893, 716.7940881549081)  7.994476
# 19 1962-08-01  695.970414   (680.3015283685405, 711.6392995495556)  7.994476
# 20 1962-09-01  586.576371   (570.9074852380605, 602.2452564190756)  7.994476
# 21 1962-10-01  518.275740  (502.60685462687246, 533.9446258078876)  7.994476
# 22 1962-11-01  449.797463  (434.12857728143047, 465.4663484624457)  7.994476
# 23 1962-12-01  499.858766   (484.1898808199104, 515.5276520009256)  7.994476
# 24 1963-01-01  511.078167   (495.4092810704933, 526.7470522515085)  7.994476
# 25 1963-02-01  481.938068  (466.26918193653927, 497.6069531175545)  7.994476
# 26 1963-03-01  539.731272   (524.0623865550464, 555.4001577360615)  7.994476
# 27 1963-04-01  549.403785   (533.7348994118435, 565.0726705928586)  7.994476
# 28 1963-05-01  568.159941   (552.4910552958212, 583.8288264768363)  7.994476
# 29 1963-06-01  655.337912   (639.6690264497632, 671.0067976307784)  7.994476
# 30 1963-07-01  750.563785   (734.8948994963622, 766.2326706773773)  7.994476
# 31 1963-08-01  744.590215   (728.9213296793463, 760.2591008603614)  7.994476
# 32 1963-09-01  626.645754   (610.9768687874308, 642.3146399684459)  7.994476
# 33 1963-10-01  553.586586    (537.9177005774619, 569.255471758477)  7.994476
# 34 1963-11-01  480.150202  (464.4813161568005, 495.81908733781574)  7.994476
# 35 1963-12-01  533.178027   (517.5091410638352, 548.8469122448503)  7.994476
#
#     forecast_lower  forecast_upper
# 0       429.664722      461.002493
# 1       404.595689      435.933460
# 2       456.773863      488.111634
# 3       463.624449      494.962220
# 4       478.987969      510.325740
# 5       554.547575      585.885347
# 6       636.183753      667.521524
# 7       631.779203      663.116975
# 8       530.897967      562.235738
# 9       467.334025      498.671796
# 10      403.793611      435.131382
# 11      450.886205      482.223976
# 12      461.575015      492.912786
# 13      435.338448      466.676219
# 14      490.353908      521.691679
# 15      498.495762      529.833533
# 16      515.678745      547.016516
# 17      597.039495      628.377266
# 18      685.456317      716.794088
# 19      680.301528      711.639300
# 20      570.907485      602.245256
# 21      502.606855      533.944626
# 22      434.128577      465.466348
# 23      484.189881      515.527652
# 24      495.409281      526.747052
# 25      466.269182      497.606953
# 26      524.062387      555.400158
# 27      533.734899      565.072671
# 28      552.491055      583.828826
# 29      639.669026      671.006798
# 30      734.894899      766.232671
# 31      728.921330      760.259101
# 32      610.976869      642.314640
# 33      537.917701      569.255472
# 34      464.481316      495.819087
# 35      517.509141      548.846912
